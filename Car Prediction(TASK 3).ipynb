# %% [markdown]
# # Car Price Predictor

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv("/kaggle/input/car-prediction/CarPrice_Assignment.csv")
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
sns.boxplot(x='fueltype', y='price', data=df)
plt.show()

# %%
plt.figure()
sns.boxplot(x='aspiration', y='price', data=df)
plt.show()

# %%
plt.figure()
sns.boxplot(x='doornumber', y='price', data=df)
plt.show()

# %%
plt.figure()
sns.boxplot(x='carbody', y='price', data=df)
plt.show()

# %%
plt.figure()
sns.boxplot(x='drivewheel', y='price', data=df)
plt.show()

# %%
plt.figure()
sns.boxplot(x='enginelocation', y='price', data=df)
plt.show()

# %% [markdown]
# # Drop Unnecessary Columns

# %%
df = df.drop(columns =['CarName','car_ID'])

# %%
df
# Out:
#      symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0            3      gas        std        two  convertible        rwd
# 1            3      gas        std        two  convertible        rwd
# 2            1      gas        std        two    hatchback        rwd
# 3            2      gas        std       four        sedan        fwd
# 4            2      gas        std       four        sedan        4wd
# ..         ...      ...        ...        ...          ...        ...
# 200         -1      gas        std       four        sedan        rwd
# 201         -1      gas      turbo       four        sedan        rwd
# 202         -1      gas        std       four        sedan        rwd
# 203         -1   diesel      turbo       four        sedan        rwd
# 204         -1      gas      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# ...

# %% [markdown]
# # Lable Encoder to convert string to integer

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['fueltype'] = le.fit_transform(df['fueltype']) 
df['aspiration'] = le.fit_transform(df['aspiration'])
df['doornumber'] = le.fit_transform(df['doornumber'])
df['carbody'] = le.fit_transform(df['carbody'])
df['drivewheel'] = le.fit_transform(df['drivewheel'])
df['enginelocation'] = le.fit_transform(df['enginelocation'])
df['enginetype'] = le.fit_transform(df['enginetype'])
df['cylindernumber'] = le.fit_transform(df['cylindernumber'])
df['fuelsystem'] = le.fit_transform(df['fuelsystem'])

# %%
df
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            3         1           0           1        0           2
# 1            3         1           0           1        0           2
# 2            1         1           0           1        2           2
# 3            2         1           0           0        3           1
# 4            2         1           0           0        3           0
# ..         ...       ...         ...         ...      ...         ...
# 200         -1         1           0           0        3           2
# 201         -1         1           1           0        3           2
# 202         -1         1           0           0        3           2
# 203         -1         0           1           0        3           2
# 204         -1         1           1           0        3           2
#
#      enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# ...

# %% [markdown]
# # Checking the correlation of columns with price

# %%
correlation_coefficient = df['stroke'].corr(df['price'])
correlation_coefficient
# Out:
# 0.079443083881931

# %%
correlation_coefficient = df[['symboling', 'fueltype','doornumber', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']].corr()['price']
correlation_coefficient
# Out:
# symboling          -0.079978
# fueltype           -0.105679
# doornumber         -0.031835
# wheelbase           0.577816
# carlength           0.682920
# carwidth            0.759325
# carheight           0.119336
# curbweight          0.835305
# enginesize          0.874145
# boreratio           0.553173
# stroke              0.079443
# compressionratio    0.067984
# horsepower          0.808139
# peakrpm            -0.085267
# citympg            -0.685751
# highwaympg         -0.697599
# price               1.000000
# Name: price, dtype: float64

# %% [markdown]
# # Splitting Data

# %%
x= df.drop(columns =['symboling','fueltype','compressionratio','peakrpm','citympg','highwaympg','price'])
x
# Out:
#      aspiration  doornumber  carbody  drivewheel  enginelocation  wheelbase  \
# 0             0           1        0           2               0       88.6
# 1             0           1        0           2               0       88.6
# 2             0           1        2           2               0       94.5
# 3             0           0        3           1               0       99.8
# 4             0           0        3           0               0       99.4
# ..          ...         ...      ...         ...             ...        ...
# 200           0           0        3           2               0      109.1
# 201           1           0        3           2               0      109.1
# 202           0           0        3           2               0      109.1
# 203           1           0        3           2               0      109.1
# 204           1           0        3           2               0      109.1
#
# ...

# %%
y=df[['price']]
y
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %% [markdown]
# # Checking the cross validation score with different algorithms

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Lasso
from sklearn.svm import SVC
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsClassifier

# %%
linear=cross_val_score(LinearRegression(), x_test, y_test,cv=9)
np.average(linear)
# Out:
# 0.7605096654339922

# %%
final=LinearRegression()
final.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
final.score(x_test,y_test)
# Out:
# 0.9327208201964192

# %% [markdown]
# # Got an Accuracy of 93 %
